# %%
# Import all the essentials

import pandas as pd
import json
import os
import matplotlib.pyplot as plot
import numpy as np   # for linear algebra
import pandas as pd  # for data frame manipulations

# %%
# This is for the k prototype

# !pip install kmodes

from kmodes.kprototypes import KPrototypes 
from sklearn.impute import KNNImputer
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
# Out:
# Requirement already satisfied: kmodes in d:\users\xyu\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: joblib>=0.11 in d:\users\xyu\anaconda3\lib\site-packages (from kmodes) (1.1.0)
# Requirement already satisfied: scipy>=0.13.3 in d:\users\xyu\anaconda3\lib\site-packages (from kmodes) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in d:\users\xyu\anaconda3\lib\site-packages (from kmodes) (1.0.2)
# Requirement already satisfied: numpy>=1.10.4 in d:\users\xyu\anaconda3\lib\site-packages (from kmodes) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\xyu\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->kmodes) (2.2.0)

# %%
# now to open the files in a list

arr = os.listdir("./Partial_Files")

all_data = []

for file in arr:
    with open ("./Partial_Files/" + str(file)) as data_file:
        data = json.load(data_file)
        all_data.append(data)

# %%
# we only want certain columns to compare, so we only normalize the columns we want

all_df = []

for data in all_data:
    df = pd.json_normalize(data)[["Product.ProductName", "ReferenceData.IllustrationID", "PolicyScalars.PremiumAmountAnnualized", "Insured1.AgeAtIssue",
                                     "PolicyScalars.FaceAmountTotal", 'Insured1.Sex']]
    all_df.append(df)

# %%
# These are additional columns that I want to add, but somehow can't...
# Some help adding these would be greatly appreciated

#                               [["Product.ProductName", "ReferenceData.IllustrationID", "PolicyScalars.PremiumAmountAnnualized", 
#                                 "Insured1.AgeAtIssue", "PolicyScalars.FaceAmountTotal", "PolicyScalars.FaceAmountBase", 
#                                 'Insured1.Sex', "PolicyScalars.PremiumMode", "PolicyScalars.PremiumAmountModal",
#                                 "PolicyScalars.PremiumAmountModal", "PolicyScalars.PremiumAmountModal", 
#                                 "PolicyScalars.PremiumDuration", "PolicyScalars.PremiumTarget", 
#                                 "PolicyScalars.PremiumMinimum", "PolicyScalars.HasLoans", "PolicyScalars.HasWithdrawals", 
#                                 "PolicyScalars.HasDistributions", "PolicyScalars.HasCreditingRates",
#                                 "PolicyScalars.HasCreditingRatesGross", "PolicyScalars.HasCreditingRatesNet", 
#                                 "PolicyScalars.IsQualifiedPlan" 
#                               ]]

# %%
# Read in the additional data excel files: 
additional_df = pd.read_excel("Additional.xlsx")

# %%
# Concatenate the files into a data frame and merge in the result,
# then we drop the illustration ID column because it's simply not useful for grouping people

result = pd.concat(all_df)
result = result.merge(additional_df, on='ReferenceData.IllustrationID')
result.drop(['ReferenceData.IllustrationID'],axis='columns', inplace=True )

# %%
# describe is a neat command to find the numerical data in a dataframe.

result.describe()
# Out:
#        PolicyScalars.PremiumAmountAnnualized  Insured1.AgeAtIssue  \
# count                             208.000000           208.000000
# mean                            28415.172548            47.716346
# std                             62458.113036            12.498553
# min                                 0.000000            20.000000
# 25%                              3220.000000            37.750000
# 50%                              9300.000000            47.000000
# 75%                             25000.000000            56.000000
# max                            500000.000000            77.000000
#
#        PolicyScalars.FaceAmountTotal
# count                   2.080000e+02
# mean                    9.848302e+05
# std                     2.831068e+06
# min                     5.000000e+04
# 25%                     2.500000e+05
# 50%                     5.000000e+05
# 75%                     1.000000e+06
# max                     3.800000e+07

# %%
# there's a whole essay on transforming NANs into values using a KNN method,
# I will look into it, but in the mean time, I will just change NANs into
# "NANs" strings, so they can be executed as normal data.

result['LISTBILL'] = result['LISTBILL'].astype(str)
result['OFFICE'] = result['OFFICE'].astype(str)
result['PARENT_OFFICE_NAME'] = result['PARENT_OFFICE_NAME'].astype(str)
result['DISTRIBUTION_CHANNEL_NAME'] = result['DISTRIBUTION_CHANNEL_NAME'].astype(str)

# %%
# Making sure there is no null values anymore.

result.isnull().sum()
# Out:
# Product.ProductName                      0
# PolicyScalars.PremiumAmountAnnualized    0
# Insured1.AgeAtIssue                      0
# PolicyScalars.FaceAmountTotal            0
# Insured1.Sex                             0
# Policy_Number                            0
# LISTBILL                                 0
# OFFICE                                   0
# PARENT_OFFICE_NAME                       0
# DISTRIBUTION_CHANNEL_NAME                0
# dtype: int64

# %%
# Now to transform the dataframe into a numpy 
# Because K-Prototype only works with numpy values

data_array = result.values
data_array[:, 1] = data_array[:, 1].astype(float)
data_array[:, 2] = data_array[:, 2].astype(float)
data_array[:, 3] = data_array[:, 3].astype(float)

# %%
# This is just the syntax for k prototyping
# There's another essay on finding the best number of clusters, 
# I will again look into it, but for now just take 3

kproto = KPrototypes(n_clusters=3, verbose=2,max_iter=20)
clusters = kproto.fit_predict(data_array, categorical=[0, 4, 5, 6, 7, 8, 9])
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 62, ncost: 656924787255749.5
# Run: 1, iteration: 2/20, moves: 35, ncost: 358761398720731.7
# Run: 1, iteration: 3/20, moves: 23, ncost: 131829567326954.94
# Run: 1, iteration: 4/20, moves: 12, ncost: 111855731668086.28
# Run: 1, iteration: 5/20, moves: 6, ncost: 87255422090975.1
# Run: 1, iteration: 6/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 23, ncost: 646450643753717.5
# Run: 2, iteration: 2/20, moves: 20, ncost: 351538983248536.94
# Run: 2, iteration: 3/20, moves: 16, ncost: 131829567326954.94
# Run: 2, iteration: 4/20, moves: 12, ncost: 111855731668086.28
# Run: 2, iteration: 5/20, moves: 6, ncost: 87255422090975.1
# Run: 2, iteration: 6/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 17, ncost: 646450643753717.5
# Run: 3, iteration: 2/20, moves: 20, ncost: 351538983248536.94
# Run: 3, iteration: 3/20, moves: 16, ncost: 131829567326954.94
# Run: 3, iteration: 4/20, moves: 12, ncost: 111855731668086.28
# Run: 3, iteration: 5/20, moves: 6, ncost: 87255422090975.1
# Run: 3, iteration: 6/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 38, ncost: 655210330445617.0
# Run: 4, iteration: 2/20, moves: 32, ncost: 358761398720731.7
# Run: 4, iteration: 3/20, moves: 23, ncost: 131829567326954.94
# Run: 4, iteration: 4/20, moves: 12, ncost: 111855731668086.28
# Run: 4, iteration: 5/20, moves: 6, ncost: 87255422090975.1
# Run: 4, iteration: 6/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 23, ncost: 647201819973815.0
# Run: 5, iteration: 2/20, moves: 15, ncost: 358761398720731.7
# Run: 5, iteration: 3/20, moves: 23, ncost: 131829567326954.94
# Run: 5, iteration: 4/20, moves: 12, ncost: 111855731668086.28
# Run: 5, iteration: 5/20, moves: 6, ncost: 87255422090975.1
# Run: 5, iteration: 6/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 28, ncost: 783113709182506.9
# Run: 6, iteration: 2/20, moves: 22, ncost: 646450643753717.5
# Run: 6, iteration: 3/20, moves: 20, ncost: 351538983248536.94
# Run: 6, iteration: 4/20, moves: 16, ncost: 131829567326954.94
# Run: 6, iteration: 5/20, moves: 12, ncost: 111855731668086.28
# Run: 6, iteration: 6/20, moves: 6, ncost: 87255422090975.1
# Run: 6, iteration: 7/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 14, ncost: 627703976721379.6
# Run: 7, iteration: 2/20, moves: 8, ncost: 337440523984025.06
# Run: 7, iteration: 3/20, moves: 11, ncost: 119638241202703.53
# Run: 7, iteration: 4/20, moves: 8, ncost: 93137093649128.81
# Run: 7, iteration: 5/20, moves: 2, ncost: 87255422090975.1
# Run: 7, iteration: 6/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 24, ncost: 627703976721379.8
# Run: 8, iteration: 2/20, moves: 8, ncost: 337440524946216.6
# Run: 8, iteration: 3/20, moves: 11, ncost: 119638241202703.53
# Run: 8, iteration: 4/20, moves: 8, ncost: 93137093649128.81
# Run: 8, iteration: 5/20, moves: 2, ncost: 87255422090975.1
# Run: 8, iteration: 6/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 36, ncost: 655210330445617.0
# Run: 9, iteration: 2/20, moves: 32, ncost: 358761398720731.7
# Run: 9, iteration: 3/20, moves: 23, ncost: 131829567326954.94
# Run: 9, iteration: 4/20, moves: 12, ncost: 111855731668086.28
# Run: 9, iteration: 5/20, moves: 6, ncost: 87255422090975.1
# Run: 9, iteration: 6/20, moves: 0, ncost: 87255422090975.1
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 104, ncost: 668177369698199.6
# Run: 10, iteration: 2/20, moves: 47, ncost: 369357908015971.25
# Run: 10, iteration: 3/20, moves: 30, ncost: 136156915603799.36
# Run: 10, iteration: 4/20, moves: 11, ncost: 119638241202703.53
# Run: 10, iteration: 5/20, moves: 8, ncost: 93137093649128.81
# Run: 10, iteration: 6/20, moves: 2, ncost: 87255422090975.1
# Run: 10, iteration: 7/20, moves: 0, ncost: 87255422090975.1
# Best run was number 1

# %%
# Cluster centroids are like where the most people have in common with each other,
# printing it out just so we can look at its values (this is where the NANs become a problem)

print(kproto.cluster_centroids_)
# Out:
# [['199500.00000000006' '44.0' '38000000.0' 'PIA6' 'Male' 'VF53729140'
#   '            ' 'PG000' 'PRODUCER GROUP RLO' 'REG LIFE OFFICES']
#  ['19730.618756218904' '47.711442786069654' '638129.815920398' 'PDXIUL2'
#   'Male' 'VF53768800' '            ' 'T372J'
#   'Transamerica Financial Advisors Inc' 'REG LIFE OFFICES']
#  ['290833.58666666667' '48.5' '6430096.833333333' 'PACHORIZONIUL' 'Male'
#   'VF53795440' '            ' 'nan' 'nan' 'WIREHOUSE']]

# %%
# We need to attach the clusters to the original data frame
# to see if we can find any patterns

cluster_dict = []
for c in clusters:
    cluster_dict.append(c)

# %%
# Make another column for the clusters:

result['cluster']=cluster_dict

# %%
result[result['cluster']== 0].head(10)
# Out:
#     Product.ProductName  PolicyScalars.PremiumAmountAnnualized  \
# 101                PIA6                               199500.0
#
#      Insured1.AgeAtIssue  PolicyScalars.FaceAmountTotal Insured1.Sex  \
# 101                   44                     38000000.0         Male
#
#     Policy_Number      LISTBILL OFFICE  PARENT_OFFICE_NAME  \
# 101    VF53729140                PG000  PRODUCER GROUP RLO
#
#     DISTRIBUTION_CHANNEL_NAME  cluster
# 101          REG LIFE OFFICES        0

# %%
result[result['cluster']== 1].head(10)
# Out:
#   Product.ProductName  PolicyScalars.PremiumAmountAnnualized  \
# 0           VFVENTURE                                8359.00
# 1             PDXIUL2                               12000.00
# 2             PDXIUL2                               21643.43
# 3             PDXIUL2                                6552.00
# 4              PSVUL2                               11504.00
# 5              PSVUL2                               11504.00
# 6              PSVUL2                                7800.00
# 7             PDXIUL2                                9600.00
# 8             PDXIUL2                                1800.00
# 9       PACADMIRALVUL                                   0.00
#
#    Insured1.AgeAtIssue  PolicyScalars.FaceAmountTotal Insured1.Sex  \
# 0                   61                       200000.0         Male
# 1                   35                       300000.0       Female
# 2                   27                       400000.0         Male
# 3                   51                       300000.0         Male
# 4                   69                       300000.0       Female
# 5                   69                       300000.0       Female
# 6                   44                      1000000.0       Female
# 7                   36                       300000.0         Male
# 8                   24                       300000.0         Male
# 9                   52                       750000.0         Male
#
#   Policy_Number      LISTBILL OFFICE                   PARENT_OFFICE_NAME  \
# 0    VF80619980  1A01R42A      0MM20                    FINANCIAL DESIGNS
# 1    VF53838600                T372J  Transamerica Financial Advisors Inc
# 2    VF53764210                T372J  Transamerica Financial Advisors Inc
# 3    VF53756940                T372J  Transamerica Financial Advisors Inc
# 4    VP66446660                0C220          CAPITAS-SMITH COMPANIES LTD
# 5    VP66446660                P725A                MORGAN STANLEY (MSSB)
# 6    VP66452840                PG000                   PRODUCER GROUP RLO
# 7    VF53745330                T372L  Transamerica Financial Advisors Inc
# 8    VF53801540                T372J  Transamerica Financial Advisors Inc
# 9    VP66442930                P931A       WELLS FARGO CLEARING SERVICES
#
#   DISTRIBUTION_CHANNEL_NAME  cluster
# 0               M FINANCIAL        1
# 1                       WFG        1
# 2                       WFG        1
# 3                       WFG        1
# 4                 WIREHOUSE        1
# 5                 WIREHOUSE        1
# 6          REG LIFE OFFICES        1
# 7                       WFG        1
# 8                       WFG        1
# 9                 WIREHOUSE        1

# %%
result[result['cluster']== 2].head(10)
# Out:
#     Product.ProductName  PolicyScalars.PremiumAmountAnnualized  \
# 85                 PIA6                               65001.56
# 109       PACHORIZONIUL                              500000.00
# 110       PACHORIZONIUL                              500000.00
# 163             PDXIUL2                              330000.00
# 174             PDXIUL2                              250000.00
# 194              PSVUL2                               99999.96
#
#      Insured1.AgeAtIssue  PolicyScalars.FaceAmountTotal Insured1.Sex  \
# 85                    56                     10000000.0         Male
# 109                   42                      7279655.0         Male
# 110                   42                      7279655.0         Male
# 163                   65                      4021271.0         Male
# 174                   46                      5000000.0         Male
# 194                   40                      5000000.0       Female
#
#     Policy_Number      LISTBILL OFFICE                   PARENT_OFFICE_NAME  \
# 85     VF53803720           nan    nan                                  nan
# 109    VF53795440                0CB20      Lion Street Private Client, Llc
# 110    VF53795440                P931B       WELLS FARGO CLEARING SERVICES
# 163    VF53763650           nan    nan                                  nan
# 174    VF53854870                T372J  Transamerica Financial Advisors Inc
# 194    VP66458690                IFP00           IND FINCL PROFESSIONAL RLO
#
#     DISTRIBUTION_CHANNEL_NAME  cluster
# 85                        nan        2
# 109                 WIREHOUSE        2
# 110                 WIREHOUSE        2
# 163                       nan        2
# 174                       WFG        2
# 194          REG LIFE OFFICES        2

# %%
# So obviously this is incomplete, cluster #1 has literally just 1 guy.

# Something we can do to improve upon that is :
# 1. actually work with the nans, instead of just bypassing them
# 2. get a bigger sample
# 3. find a more correct cluster size.
